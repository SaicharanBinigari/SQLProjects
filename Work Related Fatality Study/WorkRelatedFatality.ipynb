# %%
import pandas as pd
import numpy as np

# Task 1: Read the given dataset
def read_data_from_csv():
    df = pd.read_csv('fatality.csv')
    return df

# %%
# Task 2: Clean the given dataset
def data_cleaning():
    df = read_data_from_csv()
    df = df.drop(columns=['Unnamed'])
    return df

# %%
# Task 3: Export the cleaned dataset to "fatalities_cleaned.csv"
def export_the_dataset():
    df = data_cleaning()
    df.to_csv('fatalities_cleaned.csv', index=False)
    return df

# %%
# Call the export_the_dataset() function to execute all tasks
export_the_dataset()
# Out:
#           id incident_date day_of_week            city         state  \
# 0          1    2009-06-23   tuesday             tampa       florida
# 1          2    2009-06-30   tuesday            conroe         texas
# 2          3    2009-07-06   monday              miami       florida
# 3          4    2009-07-09   thursday     north platte      nebraska
# 4          5    2009-07-11   saturday       greensburg  pennsylvania
# ...      ...           ...         ...             ...           ...
# 14909  14910    2017-01-03   tuesday     cut and shoot         texas
# 14910  14911    2017-01-03   tuesday          glendale      kentucky
# 14911  14912    2017-01-03   tuesday         la verkin          utah
# 14912  14913    2017-01-03   tuesday    mount pleasant         texas
# 14913  14914    2017-01-02   monday           shakopee     minnesota
#
#                                              description     plan citation
# 0      Victim was inside a building bundling material...  unknown  unknown
# 1      Victim was on a scaffold doing repairs on an a...  unknown  unknown
# 2      Victim was conducting roofing work, and fell t...  unknown  unknown
# 3      Victim was climbing a ladder while servicing a...  unknown  unknown
# 4      Employees were throwing away old files. They h...  unknown  unknown
# ...                                                  ...      ...      ...
# 14909                     Worker died in fall from tree.  federal       no
# 14910                Worker fatally stabbed by resident.    state      yes
# 14911  Worker died after being struck by excavator co...    state       no
# 14912    Worker died after being struck by tanker truck.  federal      yes
# 14913             Worker died in fall inside grain tank.    state      yes
#
# [14914 rows x 8 columns]
